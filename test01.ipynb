# %%
var = 100               # 변수 선언

# %%
if 10 > 5:
    print("true")
# Out:
# true

# %%
if 10 > 5:
    print("true")
else:
    print("false")
# Out:
# true

# %%
result = 0

# %%
for i in range (1,5):           # for문 range (1,5) -> 1부터 4까지의 숫자를 원소로 가지는 객체라는 뜻
    result += i

# %%
result
# Out:
# 10

# %% [markdown]
# result

# %%
while i < 5:                    # while 반복문
    result += i
    i += 1

# %%
result
# Out:
# 14

# %%
def func(x=10, y=10):
    return x+y

# %%
func()
# Out:
# 20

# %%
func(5.5)
# Out:
# 15.5
